# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../data/external/telcos_modeling_data.xls')

# %%
df.head()
# Out:
#   CUST_ID  OUT_COMMUNITY_TOTAL  OUT_COMMUNITY_VOICE  OUT_COMMUNITY_SMS  \
# 0  C10001             9.959105             9.543413           0.755283
# 1  C10002            62.621553            61.004625          13.382496
# 2  C10003            37.708142            38.431589           3.457559
# 3  C10004            11.657388             5.812149           4.521838
# 4  C10005            22.688819            16.822096           2.902318
#
#    IN_COMMUNITY_VOICE  IN_COMMUNITY_SMS  IN_COMMUNITY_TOTAL  VOICE_OUT_CALLS  \
# 0           25.070877          3.224588           26.999948        23.938515
# 1           55.258668         14.570813           58.832688       339.326176
# 2           32.674331          5.602626           33.909000       201.631700
# 3           26.685568          7.822684           32.037527        13.380224
# 4           37.656375          3.455395           40.061273        22.682055
#
#    VOICE_IN_CALLS  SMS_OUT_CALLS  ...  PRC_IN_CALLS_PEAK  \
# ...

# %%
df.shape
# Out:
# (6624, 55)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6624 entries, 0 to 6623
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CUST_ID                      6624 non-null   object
#  1   OUT_COMMUNITY_TOTAL          6624 non-null   float64
#  2   OUT_COMMUNITY_VOICE          6624 non-null   float64
#  3   OUT_COMMUNITY_SMS            6624 non-null   float64
#  4   IN_COMMUNITY_VOICE           6624 non-null   float64
#  5   IN_COMMUNITY_SMS             6624 non-null   float64
#  6   IN_COMMUNITY_TOTAL           6624 non-null   float64
#  7   VOICE_OUT_CALLS              6624 non-null   float64
#  8   VOICE_IN_CALLS               6624 non-null   float64
#  9   SMS_OUT_CALLS                6624 non-null   float64
#  10  MMS_OUT_CALLS                6624 non-null   float64
#  11  EVENTS_CALLS                 6624 non-null   float64
# ...

# %%
df.describe()
# Out:
#        OUT_COMMUNITY_TOTAL  OUT_COMMUNITY_VOICE  OUT_COMMUNITY_SMS  \
# count          6624.000000          6624.000000        6624.000000
# mean             32.269836            28.968624           3.704776
# std              24.996685            23.369668           5.275259
# min               0.152062             0.000000           0.000000
# 25%              15.324789            13.393002           0.497163
# 50%              25.942147            22.801510           1.948303
# 75%              41.958228            37.647889           4.809508
# max             294.000941           287.704795          71.716693
#
#        IN_COMMUNITY_VOICE  IN_COMMUNITY_SMS  IN_COMMUNITY_TOTAL  \
# count         6624.000000       6624.000000         6624.000000
# mean            37.820298          6.138785           42.095787
# std             34.267828          5.572866           35.250228
# min              0.000000          0.000000            0.453059
# ...

# %%
df.plot(figsize=(12, 55), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fce6bf23280>,
# ...
#       dtype=object)
