# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd

# %%
data = pd.read_excel('../data/external/telcos_modeling_data.xls')
data
# Out:
#      CUST_ID  OUT_COMMUNITY_TOTAL  OUT_COMMUNITY_VOICE  OUT_COMMUNITY_SMS  \
# 0     C10001             9.959105             9.543413           0.755283
# 1     C10002            62.621553            61.004625          13.382496
# 2     C10003            37.708142            38.431589           3.457559
# 3     C10004            11.657388             5.812149           4.521838
# 4     C10005            22.688819            16.822096           2.902318
# ...      ...                  ...                  ...                ...
# 6619  C16620            31.112007            29.711610           1.133363
# 6620  C16621            38.640985            27.324374          19.731185
# 6621  C16622            29.058044            29.024535           0.318750
# 6622  C16623            24.861916            23.410882           0.664274
# 6623  C16624            34.582422            32.335719           0.158468
#
#       IN_COMMUNITY_VOICE  IN_COMMUNITY_SMS  IN_COMMUNITY_TOTAL  \
# ...
